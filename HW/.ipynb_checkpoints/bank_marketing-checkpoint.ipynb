# %%
from sklearn import __version__ as sklearn_version

# %%
from sklearn import datasets
import numpy as np

import pandas as pd

bank_data=pd.read_csv('./bank/bank.csv',sep=';')
bank_data=bank_data.sample(n=400)

# %%
bank_data.head()
# Out:
#       age         job  marital  education default  balance housing loan  \
# 4460   40  technician  married  secondary      no     -396     yes   no
# 4292   33  management  married   tertiary      no      752     yes   no
# 2688   27    services  married  secondary      no    -1202     yes   no
# 3184   34  management   single   tertiary      no     5086      no   no
# 3767   55   housemaid  married  secondary      no      139      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 4460   unknown   26   may       127         1     -1         0  unknown   no
# 4292  cellular   11   aug       104         4     -1         0  unknown   no
# 2688   unknown    4   jun       749         2     -1         0  unknown   no
# 3184  cellular   25   may       213         4     -1         0  unknown  yes
# 3767  cellular   22   aug       256         2     -1         0  unknown   no

# %%
bank_data=bank_data.replace({'education':'unknown','job':'unknown'},np.nan)
bank_data=bank_data.dropna()
X=bank_data.loc[:,['age','duration']]
y=bank_data.y

from sklearn.preprocessing import LabelEncoder

# Label encoding with sklearn's LabelEncoder
marital = LabelEncoder()
#X['marital'] = marital.fit_transform(X['marital'].values)
no = LabelEncoder()
y = no.fit_transform(y.values)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y)

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(n_iter=40, eta0=0.1, random_state=1)
ppn.fit(X_train_std, y_train)
y_pred=ppn.predict(X_test_std)

from sklearn.metrics import accuracy_score

print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
#print('Accuracy: %.2f' % ppn.score(X_test_std, y_test))
# Out:
# Accuracy: 0.90
# D:\Anaconda3 5.1.0\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt


def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')

    # highlight test samples
    if test_idx:
        # plot all samples
        X_test, y_test = X[test_idx, :], y[test_idx]

        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    c='',
                    edgecolor='black',
                    alpha=1.0,
                    linewidth=1,
                    marker='o',
                    s=100, 
                    label='test set')

# %%
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))


plot_decision_regions(X=X_combined_std, y=y_combined,
                      classifier=ppn, test_idx=range(len(y_train), len(y_combined)))

plt.xlabel('age [standardized]')
plt.ylabel('duration [standardized]')
plt.legend(loc='upper left')

plt.tight_layout()
#plt.savefig('images/03_01.png', dpi=300)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(C=100.0, random_state=1)
lr.fit(X_train_std, y_train)

print('Accuracy: %.2f' % lr.score(X_test_std, y_test))

plot_decision_regions(X_combined_std, y_combined,
                      classifier=lr)

plt.xlabel('age [standardized]')
plt.ylabel('duration [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_06.png', dpi=300)
plt.show()
# Out:
# Accuracy: 0.91

# %%
from sklearn.svm import SVC

svm = SVC(kernel='rbf', C=10, random_state=1)
svm.fit(X_train_std, y_train)


print('Accuracy: %.2f' % svm.score(X_test_std, y_test))


plot_decision_regions(X_combined_std, 
                      y_combined,
                      classifier=svm)

plt.xlabel('age [standardized]')
plt.ylabel('duration [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_11.png', dpi=300)
plt.show()
# Out:
# Accuracy: 0.90

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(criterion='gini', 
                              max_depth=3, 
                              random_state=1)
tree.fit(X_train, y_train)

print('Accuracy: %.2f' % tree.score(X_test, y_test))

X_combined = np.vstack((X_train, X_test))
y_combined = np.hstack((y_train, y_test))
plot_decision_regions(X_train.values, y_train, 
                      classifier=tree,resolution=0.1)


plt.xlabel('age [standardized]')
plt.ylabel('duration [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_20.png', dpi=300)
plt.show()
# Out:
# Accuracy: 0.87

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5, 
                           p=2, 
                           metric='minkowski')
knn.fit(X_train_std, y_train)

print('Accuracy: %.2f' % knn.score(X_test, y_test))

plot_decision_regions(X_combined_std, y_combined, 
                      classifier=knn)

plt.xlabel('age [standardized]')
plt.ylabel('duration [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_24.png', dpi=300)
plt.show()
# Out:
# Accuracy: 0.78

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(criterion='gini',
                                n_estimators=25, 
                                random_state=1,
                                n_jobs=2)
forest.fit(X_train, y_train)

print('Accuracy: %.2f' % forest.score(X_test, y_test))

plot_decision_regions(X_combined, y_combined, 
                      classifier=forest,resolution=0.1)

plt.xlabel('age [standardized]')
plt.ylabel('duration [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_22.png', dpi=300)
plt.show()
# Out:
# Accuracy: 0.90
