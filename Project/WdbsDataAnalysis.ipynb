# %%
from sklearn import datasets
import numpy as np

import pandas as pd

WdbsData=pd.read_csv('./WdbsData.csv',sep=',')
WdbsData=WdbsData.sample(n=400)

# %%
WdbsData.head()
# Out:
#            id diagnosis  radius mean  texture mean  perimeter mean  area mean  \
# 42     855625         M        19.07         24.81          128.30     1104.0
# 540    921385         B        11.54         14.44           74.65      402.9
# 509    915460         M        15.46         23.95          103.80      731.3
# 138    868826         M        14.95         17.57           96.85      678.1
# 311  89382601         B        14.61         15.69           92.68      664.9
#
#      smoothness mean  compactness mean  concavity mean  concave points mean  \
# 42           0.09081           0.21900         0.21070              0.09961
# 540          0.09984           0.11200         0.06737              0.02594
# 509          0.11830           0.18700         0.20300              0.08520
# 138          0.11670           0.13050         0.15390              0.08624
# 311          0.07618           0.03515         0.01447              0.01877
#
# ...
